# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://api.db.nomics.world/v22/series/AMECO/UDGG.csv?dimensions=%7B%22freq%22%3A%5B%22a%22%5D%2C%22unit%22%3A%5B%22percentage-of-gdp-at-current-prices-excessive-deficit-procedure%22%5D%2C%22geo%22%3A%5B%22deu%22%2C%22ita%22%2C%22fra%22%2C%22esp%22%5D%7D&limit=1000"

df_debt = pd.read_csv(url)

df_debt.to_csv('data/df_debt.csv', sep = ",", index = False)

# %%
df_debt
# Out:
#     period  \
# 0     1960
# 1     1961
# 2     1962
# 3     1963
# 4     1964
# ..     ...
# 61    2021
# 62    2022
# 63    2023
# 64    2024
# 65    2025
#
#     Annually – (Percentage of GDP at current prices (excessive deficit procedure)) – Germany (AMECO/UDGG/DEU.1.0.319.0.UDGG)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 61                                            68.9861
# 62                                            66.0769
# 63                                            63.6391
# 64                                            62.9344
# 65                                            62.1991
#
#     Annually – (Percentage of GDP at current prices (excessive deficit procedure)) – Spain (AMECO/UDGG/ESP.1.0.319.0.UDGG)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 61                                           116.8408
# 62                                           111.6180
# 63                                           107.6521
# 64                                           105.5079
# 65                                           104.8290
#
#     Annually – (Percentage of GDP at current prices (excessive deficit procedure)) – France (AMECO/UDGG/FRA.1.0.319.0.UDGG)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 61                                           112.9733
# 62                                           111.9182
# 63                                           110.6433
# 64                                           112.4088
# 65                                           113.8249
#
#     Annually – (Percentage of GDP at current prices (excessive deficit procedure)) – Italy (AMECO/UDGG/ITA.1.0.319.0.UDGG)
# 0                                             31.7953
# 1                                             29.9336
# 2                                             28.7905
# 3                                             26.8476
# 4                                             26.6785
# ..                                                ...
# 61                                           147.1270
# 62                                           140.5217
# 63                                           137.3104
# 64                                           138.6244
# 65                                           141.6909
#
# [66 rows x 5 columns]

# %%
new_names = {
    df_debt.columns[0]: "Year",
    df_debt.columns[1]: "Germany",
    df_debt.columns[2]: "Spain",
    df_debt.columns[3]: "France",
    df_debt.columns[4]: "Italy",
}

# %%
df_debt.rename(columns = new_names, inplace = True)

# %%
df_debt.head()
# Out:
#    Year  Germany  Spain  France    Italy
# 0  1960      NaN    NaN     NaN  31.7953
# 1  1961      NaN    NaN     NaN  29.9336
# 2  1962      NaN    NaN     NaN  28.7905
# 3  1963      NaN    NaN     NaN  26.8476
# 4  1964      NaN    NaN     NaN  26.6785

# %%
df_debt.isna().sum()
# Out:
# Year        0
# Germany    35
# Spain      35
# France     35
# Italy       0
# dtype: int64

# %%
df_debt.dropna(inplace=True)

df_debt.head()
# Out:
#     Year  Germany    Spain   France     Italy
# 35  1995  54.9024  61.5424  57.5929  119.3622
# 36  1996  57.7939  65.4076  60.3374  119.1093
# 37  1997  58.8666  64.2495  61.8342  116.7821
# 38  1998  59.5347  62.3060  61.8435  114.1269
# 39  1999  60.3874  60.8039  61.1666  113.2895

# %%
df_debt.reset_index(drop=True, inplace=True)
df_debt.head()
# Out:
#    Year  Germany    Spain   France     Italy
# 0  1995  54.9024  61.5424  57.5929  119.3622
# 1  1996  57.7939  65.4076  60.3374  119.1093
# 2  1997  58.8666  64.2495  61.8342  116.7821
# 3  1998  59.5347  62.3060  61.8435  114.1269
# 4  1999  60.3874  60.8039  61.1666  113.2895

# %%
df_debt
# Out:
#     Year  Germany     Spain    France     Italy
# 0   1995  54.9024   61.5424   57.5929  119.3622
# 1   1996  57.7939   65.4076   60.3374  119.1093
# 2   1997  58.8666   64.2495   61.8342  116.7821
# 3   1998  59.5347   62.3060   61.8435  114.1269
# 4   1999  60.3874   60.8039   61.1666  113.2895
# 5   2000  59.3398   57.8153   59.5167  109.0258
# 6   2001  58.1930   54.0495   59.0088  108.8863
# 7   2002  59.9458   51.2499   60.8896  106.3605
# 8   2003  63.5383   47.7117   65.0290  105.4946
# 9   2004  65.2009   45.3655   66.5689  105.1009
# 10  2005  67.5463   42.4302   68.0371  106.5575
# 11  2006  66.8871   39.0639   65.3254  106.7398
# 12  2007  64.1583   35.7646   65.3593  103.8902
# 13  2008  65.6816   39.7120   69.7358  106.1670
# 14  2009  73.1566   53.2613   84.0304  116.6155
# 15  2010  81.9947   60.5153   86.3119  119.2080
# 16  2011  79.4172   69.8504   88.9120  119.7072
# 17  2012  80.7451   89.9825   91.7192  126.5107
# 18  2013  78.3224  100.4877   94.6870  132.4748
# 19  2014  75.2791  105.0588   96.3165  135.3842
# 20  2015  71.9465  103.2993   97.0724  135.2990
# 21  2016  68.9547  102.7485   98.0251  134.8040
# 22  2017  65.2042  101.7996   98.4852  134.1838
# 23  2018  61.9137  100.4155   98.1581  134.4695
# 24  2019  59.5804   98.2210   97.8872  134.1910
# 25  2020  68.7730  120.2658  114.8532  154.9537
# 26  2021  68.9861  116.8408  112.9733  147.1270
# 27  2022  66.0769  111.6180  111.9182  140.5217
# 28  2023  63.6391  107.6521  110.6433  137.3104
# 29  2024  62.9344  105.5079  112.4088  138.6244
# 30  2025  62.1991  104.8290  113.8249  141.6909

# %%
x = df_debt['Year']
countries = ["Germany", "Spain", "France", "Italy"]

for country in countries:
    plt.plot(x, df_debt[country], label = country)

plt.legend();

# %%
df_debt_long = pd.melt(
    df_debt,
    id_vars = 'Year',
    var_name = 'Country',
    value_name = 'Debt ratio'
)

# %%
df_debt_long
# Out:
#      Year  Country  Debt ratio
# 0    1995  Germany     54.9024
# 1    1996  Germany     57.7939
# 2    1997  Germany     58.8666
# 3    1998  Germany     59.5347
# 4    1999  Germany     60.3874
# ..    ...      ...         ...
# 119  2021    Italy    147.1270
# 120  2022    Italy    140.5217
# 121  2023    Italy    137.3104
# 122  2024    Italy    138.6244
# 123  2025    Italy    141.6909
#
# [124 rows x 3 columns]

# %%
sns.lineplot(x= "Year",
            y = "Debt ratio",
            hue= "Country",
            data = df_debt_long);

# %%
df_debt_wide = pd.pivot(
    df_debt_long,
    index = 'Year', 
    columns = 'Country', 
    values = 'Debt ratio'
).reset_index()

# %%
df_debt_wide
# Out:
# Country  Year    France  Germany     Italy     Spain
# 0        1995   57.5929  54.9024  119.3622   61.5424
# 1        1996   60.3374  57.7939  119.1093   65.4076
# 2        1997   61.8342  58.8666  116.7821   64.2495
# 3        1998   61.8435  59.5347  114.1269   62.3060
# 4        1999   61.1666  60.3874  113.2895   60.8039
# 5        2000   59.5167  59.3398  109.0258   57.8153
# 6        2001   59.0088  58.1930  108.8863   54.0495
# 7        2002   60.8896  59.9458  106.3605   51.2499
# 8        2003   65.0290  63.5383  105.4946   47.7117
# 9        2004   66.5689  65.2009  105.1009   45.3655
# 10       2005   68.0371  67.5463  106.5575   42.4302
# 11       2006   65.3254  66.8871  106.7398   39.0639
# 12       2007   65.3593  64.1583  103.8902   35.7646
# 13       2008   69.7358  65.6816  106.1670   39.7120
# 14       2009   84.0304  73.1566  116.6155   53.2613
# 15       2010   86.3119  81.9947  119.2080   60.5153
# 16       2011   88.9120  79.4172  119.7072   69.8504
# 17       2012   91.7192  80.7451  126.5107   89.9825
# 18       2013   94.6870  78.3224  132.4748  100.4877
# 19       2014   96.3165  75.2791  135.3842  105.0588
# 20       2015   97.0724  71.9465  135.2990  103.2993
# 21       2016   98.0251  68.9547  134.8040  102.7485
# 22       2017   98.4852  65.2042  134.1838  101.7996
# 23       2018   98.1581  61.9137  134.4695  100.4155
# 24       2019   97.8872  59.5804  134.1910   98.2210
# 25       2020  114.8532  68.7730  154.9537  120.2658
# 26       2021  112.9733  68.9861  147.1270  116.8408
# 27       2022  111.9182  66.0769  140.5217  111.6180
# 28       2023  110.6433  63.6391  137.3104  107.6521
# 29       2024  112.4088  62.9344  138.6244  105.5079
# 30       2025  113.8249  62.1991  141.6909  104.8290
